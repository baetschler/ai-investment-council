# %%
pip install google-adk
# Out:
# Requirement already satisfied: google-adk in ./.venv/lib/python3.14/site-packages (1.19.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in ./.venv/lib/python3.14/site-packages (from google-adk) (6.0.3)
# Requirement already satisfied: aiosqlite>=0.21.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (0.21.0)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in ./.venv/lib/python3.14/site-packages (from google-adk) (8.3.1)
# Requirement already satisfied: fastapi<0.119.0,>=0.115.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (0.118.3)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in ./.venv/lib/python3.14/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.128.0)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (3.38.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in ./.venv/lib/python3.14/site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=3.0.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (3.6.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.52.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in ./.venv/lib/python3.14/site-packages (from google-adk) (0.21)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (4.25.1)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.22.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pyarrow>=14.0.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (22.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (2.12.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in ./.venv/lib/python3.14/site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in ./.venv/lib/python3.14/site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (2.0.44)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in ./.venv/lib/python3.14/site-packages (from google-adk) (0.48.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in ./.venv/lib/python3.14/site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in ./.venv/lib/python3.14/site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in ./.venv/lib/python3.14/site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in ./.venv/lib/python3.14/site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.14/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.14/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in ./.venv/lib/python3.14/site-packages (from authlib<2.0.0,>=1.5.1->google-adk) (46.0.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in ./.venv/lib/python3.14/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in ./.venv/lib/python3.14/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in ./.venv/lib/python3.14/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in ./.venv/lib/python3.14/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in ./.venv/lib/python3.14/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in ./.venv/lib/python3.14/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in ./.venv/lib/python3.14/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.33.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in ./.venv/lib/python3.14/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in ./.venv/lib/python3.14/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.14/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.14/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: packaging>=14.3 in ./.venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in ./.venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in ./.venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in ./.venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in ./.venv/lib/python3.14/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in ./.venv/lib/python3.14/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in ./.venv/lib/python3.14/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in ./.venv/lib/python3.14/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in ./.venv/lib/python3.14/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in ./.venv/lib/python3.14/site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in ./.venv/lib/python3.14/site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.8.0)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in ./.venv/lib/python3.14/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in ./.venv/lib/python3.14/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in ./.venv/lib/python3.14/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.14.3)
# Requirement already satisfied: sqlparse>=0.4.4 in ./.venv/lib/python3.14/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in ./.venv/lib/python3.14/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in ./.venv/lib/python3.14/site-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (1.7.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in ./.venv/lib/python3.14/site-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in ./.venv/lib/python3.14/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.5)
# Requirement already satisfied: certifi in ./.venv/lib/python3.14/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.14/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.14/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.14/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.14/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.14/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.29.0)
# Requirement already satisfied: httpx-sse>=0.4 in ./.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in ./.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in ./.venv/lib/python3.14/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in ./.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in ./.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in ./.venv/lib/python3.14/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in ./.venv/lib/python3.14/site-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.14/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in ./.venv/lib/python3.14/site-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in ./.venv/lib/python3.14/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in ./.venv/lib/python3.14/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in ./.venv/lib/python3.14/site-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.5)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in ./.venv/lib/python3.14/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in ./.venv/lib/python3.14/site-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.3.5)
# Requirement already satisfied: cffi>=2.0.0 in ./.venv/lib/python3.14/site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.23)
# Requirement already satisfied: alembic in ./.venv/lib/python3.14/site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.2)
# Requirement already satisfied: Mako in ./.venv/lib/python3.14/site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: MarkupSafe>=0.9.2 in ./.venv/lib/python3.14/site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load environment variables
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
DATA_PROVIDER_SYSTEM = """
Du bist 'data_provider', eine spezialisierte Daten-KI für ein Investment-Committee.
Du benutzt ausschließlich das Tool GOOGLE_SEARCH, um Informationen zu einem Asset zu beschaffen.

Deine Aufgabe:
- Nimm eine simple Text-Beschreibung des Assets entgegen (z.B. Ticker oder Name).
- Führe bis zu 3 Web-Suchen durch (Tool GOOGLE_SEARCH).
- Extrahiere, soweit möglich:
  - aktuellen Preis
  - Marktkapitalisierung
  - grobe Bewertung (z.B. KGV)
  - 1-2 makro-relevante Stichworte (z.B. "Tech US", "EM", "Crypto")
  - 2-3 aktuelle Schlagzeilen

WICHTIG:
- Erfinde keine Zahlen. Wenn du nichts Sicheres findest, nutze null.
Antworte nur mit einem JSON-Objekt im geforderten Format, ohne zusätzlichen Text.

{
  "price": float oder null,
  "market_cap": str oder null,
  "pe_ratio": float oder null,
  "macro_tags": [str, ...],
  "headlines": [str, ...]
}
"""

XO_SYSTEM = """
Du bist 'xo', ein technischer Trader im Stil von TraderXO.
Du kommentierst NICHT das Makro-Umfeld und machst KEINE Websuche.
Du bekommst ein Dictionary mit Basisdaten zu einem Asset (price, headlines etc.).

Deine Aufgabe:
- Triff eine einfache technische Einschätzung:
  - direction: "long", "short" oder "neutral"
  - setup: "range", "breakout", "pullback" oder "unknown"
  - confidence: Zahl von 0 bis 100

Du darfst Annahmen machen, aber sei diszipliniert: Wenn du nicht genug Infos siehst, setze
direction auf "neutral" und confidence niedrig.

Gib NUR folgendes Dictionary zurück:

{
  "direction": "...",
  "setup": "...",
  "confidence": <int>
}
"""

GLOBAL_SYSTEM = """
Du bist 'global', eine Makro-KI, die globale Geldflüsse und das gesamtwirtschaftliche Risiko einschätzt.
Du bekommst ein Dictionary mit Basisdaten (price, market_cap, headlines, macro_tags).

Deine Aufgabe:
- Bestimme ein grobes Makro-Regime:
  - macro_regime: "risk_on", "neutral", "risk_off"
- Schätze eine grobe Liquiditätslage:
  - liquidity: 0-100

Regeln:
- Viele positive Wachstums-/Tech-/Risikobegriffe -> eher "risk_on".
- Viele Begriffe zu Rezession, Krise, Restriktionen -> eher "risk_off".
- Wenn unklar, "neutral".

Antwort ausschließlich als Dictionary:

{
  "macro_regime": "...",
  "liquidity": <int>
}
"""

WARREN_SYSTEM = """
Du bist 'warren', ein Value-Investor im Stil von Warren Buffett.
Du bekommst ein JSON-Dictionary mit Basisdaten: price, market_cap, pe_ratio, headlines.

Deine Aufgabe:
- Schätze grob:
  - value_opinion: "undervalued", "fair", "overvalued" oder "unknown"
  - quality: 0-100 (Gefühl für Qualität, Moat, Management, Geschäft)

Heuristik:
- Sehr hohes KGV und stark gehypte Headlines -> eher "overvalued".
- Moderates KGV, solide/hemdsärmelige Headlines -> eher "fair" oder "undervalued".
- Wenn wenig Infos: "unknown", niedrige quality.

Antwort ausschließlich als Dictionary:

{
  "value_opinion": "...",
  "quality": <int>
}
"""

ROUNDTABLE_SYSTEM = """
Du bist 'roundtable', ein Diskussions-Agent.

Dir stehen folgende Tools zur Verfügung:
- XO_Agent (TraderXO-Sicht)
- Global_Agent (Makro-Sicht)
- Warren_Agent (Value-Sicht)

Du hast vorbereitete Asset-Daten im Kontext:

{asset_data}

Vorgehen:

1. Behandle {asset_data} als JSON-Objekt mit Feldern wie price, market_cap, pe_ratio, macro_tags, headlines.
2. Rufe GENAU EINMAL nacheinander diese Tools auf:
   - XO_Agent
   - Global_Agent
   - Warren_Agent

   Verwende dabei jeweils das gleiche Argument-Objekt:
   {
     "input": {asset_data}
   }

3. Warte auf die Antworten der Tools. Jede Antwort ist ein JSON-Objekt:
   - XO_Agent:
     { "direction": "...", "setup": "...", "confidence": <int> }
   - Global_Agent:
     { "macro_regime": "...", "liquidity": <int> }
   - Warren_Agent:
     { "value_opinion": "...", "quality": <int> }

4. Fasse die Ergebnisse in einer Liste von Strings zusammen, z.B.:

[
  "TraderXO: Richtung long, Setup range, Confidence 72.",
  "Global: Makro-Regime risk_on, Liquidity 65.",
  "Warren: Einschätzung fair bewertet, Quality 80.",
  "Fazit: Bei moderatem Risiko könnte ein gestaffelter Einstieg sinnvoll sein, aber beachte Volatilität und Nachrichtenlage."
]

Regeln:
- Bleib kurz und prägnant pro String.
- Nutze keine Floskeln, sondern konkrete Informationen aus den drei Antworten.
- Gib AUSSCHLIESSLICH eine JSON-Liste von Strings zurück, ohne zusätzlichen Text.
"""

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction=DATA_PROVIDER_SYSTEM,
    tools=[google_search],
    output_key="asset_data",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
xo_agent = Agent(
    name="XO_Agent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction=XO_SYSTEM,
    tools=[],
    output_key="xo_raw",  # The result of this agent will be stored in the session state with this key.
)

print("✅ XO_Agent created.")
# Out:
# ✅ XO_Agent created.

# %%
warren_agent = Agent(
    name="Warren_Agent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction=WARREN_SYSTEM,
    tools=[],
    output_key="warren_raw",  # The result of this agent will be stored in the session state with this key.
)

print("✅ Warren_Agent created.")
# Out:
# ✅ Warren_Agent created.

# %%
global_agent = Agent(
    name="Global_Agent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction=GLOBAL_SYSTEM,
    tools=[],
    output_key="global_raw",  # The result of this agent will be stored in the session state with this key.
)

print("✅ Global_agent created.")
# Out:
# ✅ Global_agent created.

# %%
# roundtable Agent: 
roundtable_agent = Agent(
    name="RoundtableAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config,
    ),
    instruction=ROUNDTABLE_SYSTEM,
    tools=[AgentTool(xo_agent), AgentTool(global_agent), AgentTool(warren_agent)],
    output_key="roundtable_findings",
)
print(f"✅ RoundtableAgent with {[a.name for a in roundtable_agent.tools]} created.")
# Out:
# ✅ RoundtableAgent with ['XO_Agent', 'Global_Agent', 'Warren_Agent'] created.

# %%
# Investment Pipeline: Its job is to coordinate the research and roundtable agents.
investment_pipeline = SequentialAgent(
    name="investment_pipeline",
    sub_agents=[research_agent, roundtable_agent],
)

print(f"✅ Investment_Pipeline for sequential workflow with {[a.name for a in investment_pipeline.sub_agents]} created.")
# Out:
# ✅ Investment_Pipeline for sequential workflow with ['ResearchAgent', 'RoundtableAgent'] created.

# %%
runner = InMemoryRunner(agent=investment_pipeline)
response = await runner.run_debug(
    "What is the current investment outlook for Tesla (TSLA)?"
)
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/Users/kaibachler/Google Agent/2b/Google Capstone Project/.venv/lib/python3.14/site-packages/google/adk/agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > What is the current investment outlook for Tesla (TSLA)?
# ResearchAgent > I am sorry, but I cannot provide a real-time stock price. However, I can give you the latest available data on Tesla (TSLA) from November 25, 2025.
#
# ```json
# {
#   "price": null,
#   "market_cap": "$1.39 trillion",
#   "pe_ratio": 276.85,
#   "macro_tags": [
#     "Automotive",
#     "Electric Vehicles",
#     "Technology",
#     "US"
#   ],
#   "headlines": [
#     "Tesla accused of infringing robotics patents in new lawsuit.",
#     "Tesla breaks Norway's all-time annual sales record with one month to spare.",
#     "Tesla China announced that the company's Autopilot system has accumulated 10 billion kilometers of driving experience."
#   ]
# }
# ```
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/Users/kaibachler/Google Agent/2b/Google Capstone Project/.venv/lib/python3.14/site-packages/google/adk/agents", which implies app name "agents".
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/Users/kaibachler/Google Agent/2b/Google Capstone Project/.venv/lib/python3.14/site-packages/google/adk/agents", which implies app name "agents".
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/Users/kaibachler/Google Agent/2b/Google Capstone Project/.venv/lib/python3.14/site-packages/google/adk/agents", which implies app name "agents".
# RoundtableAgent > [
#   "TraderXO: Richtung neutral, Setup unbekannt, Confidence 20.",
#   "Global: Makro-Regime neutral, Liquidität 50.",
#   "Warren: Einschätzung überbewertet, Quality 75.",
#   "Fazit: Angesichts der neutralen Marktindikatoren und der überbewerteten Einschätzung ist Vorsicht geboten. Die Nachrichtenlage könnte die Volatilität beeinflussen."
# ]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 6
#       1 runner = InMemoryRunner(agent=investment_pipeline)
#       2 response = await runner.run_debug(
#       3     "What is the current investment outlook for Tesla (TSLA)?"
#       4 )
# ----> 6 print(runner.getstate())
#
# AttributeError: 'InMemoryRunner' object has no attribute 'getstate'

# %%
dir(runner.session_service.__getstate__)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__text_signature__']
